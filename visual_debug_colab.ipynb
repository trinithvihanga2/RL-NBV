# %% [markdown]
# # RL-NBV Visual Debugger (Colab)
# This notebook allows you to run the visual debugging script in Google Colab and view the rendered frames inline.

# %%
# !pip install stable-baselines3 gymnasium pyyaml pillow matplotlib

# %% [markdown]
# ## 1. Setup the Repository
# Clone the repository from GitHub and navigate into it.

# %%
# Note: Cloning via SSH requires SSH keys configured in Colab.
# !git clone https://github.com/trinithvihanga2/RL-NBV.git
# %cd RL-NBV

# %% [markdown]
# ## 2. Run the Visual Debugger
# Make sure you upload your trained model (`.zip`) to the Colab environment (inside the `RL-NBV` folder).

# %%
# !python visual_debug.py --model_path artefacts/train/final.zip --output_dir debug_renders --episodes 1

# %% [markdown]
# ## 3. View the Output
# Display the generated renders inline in the notebook.

# %%
import glob
import matplotlib.pyplot as plt
from PIL import Image
from IPython.display import display

image_paths = sorted(glob.glob('debug_renders/*.png'))
for path in image_paths:
    img = Image.open(path)
    display(img)
